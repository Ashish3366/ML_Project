# %% [markdown]
# # Decision Tree on Titanic Datasset

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df = df.drop(['PassengerId','Name','Ticket','Cabin'],axis=1)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df.isnull().sum() #finding null values present in each column
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
sum(df.duplicated())
# Out:
# 38

# %%
df = df.drop_duplicates()

# %%
sum(df.duplicated())
# Out:
# 0

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 883         0       2    male  28.0      0      0  10.5000        S
# 885         0       3  female  39.0      0      5  29.1250        Q
# 887         1       1  female  19.0      0      0  30.0000        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [674 rows x 8 columns]

# %%
df = pd.get_dummies(df,columns=['Embarked'])

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare  Embarked_C  \
# 0           0       3    male  22.0      1      0   7.2500           0
# 1           1       1  female  38.0      1      0  71.2833           1
# 2           1       3  female  26.0      0      0   7.9250           0
# 3           1       1  female  35.0      1      0  53.1000           0
# 4           0       3    male  35.0      0      0   8.0500           0
# ..        ...     ...     ...   ...    ...    ...      ...         ...
# 883         0       2    male  28.0      0      0  10.5000           0
# 885         0       3  female  39.0      0      5  29.1250           0
# 887         1       1  female  19.0      0      0  30.0000           0
# 889         1       1    male  26.0      0      0  30.0000           1
# 890         0       3    male  32.0      0      0   7.7500           0
#
#      Embarked_Q  Embarked_S
# 0             0           1
# 1             0           0
# 2             0           1
# 3             0           1
# 4             0           1
# ..          ...         ...
# 883           0           1
# 885           1           0
# 887           0           1
# 889           0           0
# 890           1           0
#
# [674 rows x 10 columns]

# %%
df['Sex'].replace(['male','female'],[0,1],inplace=True)

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  \
# 0           0       3    0  22.0      1      0   7.2500           0
# 1           1       1    1  38.0      1      0  71.2833           1
# 2           1       3    1  26.0      0      0   7.9250           0
# 3           1       1    1  35.0      1      0  53.1000           0
# 4           0       3    0  35.0      0      0   8.0500           0
# ..        ...     ...  ...   ...    ...    ...      ...         ...
# 883         0       2    0  28.0      0      0  10.5000           0
# 885         0       3    1  39.0      0      5  29.1250           0
# 887         1       1    1  19.0      0      0  30.0000           0
# 889         1       1    0  26.0      0      0  30.0000           1
# 890         0       3    0  32.0      0      0   7.7500           0
#
#      Embarked_Q  Embarked_S
# 0             0           1
# 1             0           0
# 2             0           1
# 3             0           1
# 4             0           1
# ..          ...         ...
# 883           0           1
# 885           1           0
# 887           0           1
# 889           0           0
# 890           1           0
#
# [674 rows x 10 columns]

# %%
x = df.drop(['Survived'],axis=1)
y = df['Survived']

# %%
x
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  Embarked_Q  \
# 0         3    0  22.0      1      0   7.2500           0           0
# 1         1    1  38.0      1      0  71.2833           1           0
# 2         3    1  26.0      0      0   7.9250           0           0
# 3         1    1  35.0      1      0  53.1000           0           0
# 4         3    0  35.0      0      0   8.0500           0           0
# ..      ...  ...   ...    ...    ...      ...         ...         ...
# 883       2    0  28.0      0      0  10.5000           0           0
# 885       3    1  39.0      0      5  29.1250           0           1
# 887       1    1  19.0      0      0  30.0000           0           0
# 889       1    0  26.0      0      0  30.0000           1           0
# 890       3    0  32.0      0      0   7.7500           0           1
#
#      Embarked_S
# 0             1
# 1             0
# 2             1
# 3             1
# 4             1
# ..          ...
# 883           1
# 885           0
# 887           1
# 889           0
# 890           0
#
# [674 rows x 9 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 883    0
# 885    0
# 887    1
# 889    1
# 890    0
# Name: Survived, Length: 674, dtype: int64

# %% [markdown]
# # Ploting Decision Tree

# %%
from sklearn import tree as t

# %%
model = t.DecisionTreeClassifier(max_depth = 3)

# %%
model.fit(x,y)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (15,10) )
t.plot_tree(model)
# Out:
# [Text(418.5, 475.65000000000003, 'X[1] <= 0.5\ngini = 0.486\nsamples = 674\nvalue = [393, 281]'),
#  Text(209.25, 339.75, 'X[2] <= 6.5\ngini = 0.342\nsamples = 421\nvalue = [329, 92]'),
#  Text(104.625, 203.85000000000002, 'X[3] <= 2.5\ngini = 0.444\nsamples = 24\nvalue = [8, 16]'),
#  Text(52.3125, 67.94999999999999, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(156.9375, 67.94999999999999, 'gini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(313.875, 203.85000000000002, 'X[0] <= 1.5\ngini = 0.31\nsamples = 397\nvalue = [321, 76]'),
#  Text(261.5625, 67.94999999999999, 'gini = 0.475\nsamples = 98\nvalue = [60, 38]'),
#  Text(366.1875, 67.94999999999999, 'gini = 0.222\nsamples = 299\nvalue = [261, 38]'),
#  Text(627.75, 339.75, 'X[0] <= 2.5\ngini = 0.378\nsamples = 253\nvalue = [64, 189]'),
#  Text(523.125, 203.85000000000002, 'X[2] <= 2.5\ngini = 0.111\nsamples = 152\nvalue = [9, 143]'),
#  Text(470.8125, 67.94999999999999, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(575.4375, 67.94999999999999, 'gini = 0.101\nsamples = 150\nvalue = [8, 142]'),
#  Text(732.375, 203.85000000000002, 'X[5] <= 20.8\ngini = 0.496\nsamples = 101\nvalue = [55, 46]'),
#  Text(680.0625, 67.94999999999999, 'gini = 0.495\nsamples = 78\nvalue = [35, 43]'),
#  Text(784.6875, 67.94999999999999, 'gini = 0.227\nsamples = 23\nvalue = [20, 3]')]

# %%
plt.figure(figsize = (15,10) )
t.plot_tree(model,filled=True)
# Out:
# [Text(418.5, 475.65000000000003, 'X[1] <= 0.5\ngini = 0.486\nsamples = 674\nvalue = [393, 281]'),
#  Text(209.25, 339.75, 'X[2] <= 6.5\ngini = 0.342\nsamples = 421\nvalue = [329, 92]'),
#  Text(104.625, 203.85000000000002, 'X[3] <= 2.5\ngini = 0.444\nsamples = 24\nvalue = [8, 16]'),
#  Text(52.3125, 67.94999999999999, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(156.9375, 67.94999999999999, 'gini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(313.875, 203.85000000000002, 'X[0] <= 1.5\ngini = 0.31\nsamples = 397\nvalue = [321, 76]'),
#  Text(261.5625, 67.94999999999999, 'gini = 0.475\nsamples = 98\nvalue = [60, 38]'),
#  Text(366.1875, 67.94999999999999, 'gini = 0.222\nsamples = 299\nvalue = [261, 38]'),
#  Text(627.75, 339.75, 'X[0] <= 2.5\ngini = 0.378\nsamples = 253\nvalue = [64, 189]'),
#  Text(523.125, 203.85000000000002, 'X[2] <= 2.5\ngini = 0.111\nsamples = 152\nvalue = [9, 143]'),
#  Text(470.8125, 67.94999999999999, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(575.4375, 67.94999999999999, 'gini = 0.101\nsamples = 150\nvalue = [8, 142]'),
#  Text(732.375, 203.85000000000002, 'X[5] <= 20.8\ngini = 0.496\nsamples = 101\nvalue = [55, 46]'),
#  Text(680.0625, 67.94999999999999, 'gini = 0.495\nsamples = 78\nvalue = [35, 43]'),
#  Text(784.6875, 67.94999999999999, 'gini = 0.227\nsamples = 23\nvalue = [20, 3]')]

# %%
#from sklearn import metrics
#metrics.accuracy_score(y_test,y_pred)

# %%
model.score(x,y)
# Out:
# 0.8160237388724035
