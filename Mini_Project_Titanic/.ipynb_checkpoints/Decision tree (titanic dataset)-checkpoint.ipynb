# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn import tree

# %%
import seaborn as sns
df=sns.load_dataset('titanic')

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
df = df.drop(['age','deck','embark_town','embarked'],1)
# Out:
# C:\Users\chetan\AppData\Local\Temp/ipykernel_10964/4002048906.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop(['age','deck','embark_town','embarked'],1)

# %%
df
# Out:
#      survived  pclass     sex  sibsp  parch     fare   class    who  \
# 0           0       3    male      1      0   7.2500   Third    man
# 1           1       1  female      1      0  71.2833   First  woman
# 2           1       3  female      0      0   7.9250   Third  woman
# 3           1       1  female      1      0  53.1000   First  woman
# 4           0       3    male      0      0   8.0500   Third    man
# ..        ...     ...     ...    ...    ...      ...     ...    ...
# 886         0       2    male      0      0  13.0000  Second    man
# 887         1       1  female      0      0  30.0000   First  woman
# 888         0       3  female      1      2  23.4500   Third  woman
# 889         1       1    male      0      0  30.0000   First    man
# 890         0       3    male      0      0   7.7500   Third    man
#
#      adult_male alive  alone
# 0          True    no  False
# 1         False   yes  False
# 2         False   yes   True
# 3         False   yes  False
# 4          True    no   True
# ..          ...   ...    ...
# 886        True    no   True
# 887       False   yes   True
# 888       False    no  False
# 889        True   yes   True
# 890        True    no   True
#
# [891 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# sibsp         0
# parch         0
# fare          0
# class         0
# who           0
# adult_male    0
# alive         0
# alone         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 388

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['sex'].replace(['male','female'],[0,1],inplace=True)
# Out:
# C:\Users\chetan\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
df['alive'] = df['alive'].map(
                   {'yes':1 ,'no':0})
# Out:
# C:\Users\chetan\AppData\Local\Temp/ipykernel_10964/751641064.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['alive'] = df['alive'].map(

# %%
df=df.drop('who',1)
# Out:
# C:\Users\chetan\AppData\Local\Temp/ipykernel_10964/2202077312.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df=df.drop('who',1)

# %%
df=df.drop('class',1)
# Out:
# C:\Users\chetan\AppData\Local\Temp/ipykernel_10964/3791318868.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df=df.drop('class',1)

# %%
x=df.drop('survived',1)
# Out:
# C:\Users\chetan\AppData\Local\Temp/ipykernel_10964/2639322056.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   x=df.drop('survived',1)

# %%
x
# Out:
#      pclass  sex  sibsp  parch     fare  adult_male  alive  alone
# 0         3    0      1      0   7.2500        True      0  False
# 1         1    1      1      0  71.2833       False      1  False
# 2         3    1      0      0   7.9250       False      1   True
# 3         1    1      1      0  53.1000       False      1  False
# 4         3    0      0      0   8.0500        True      0   True
# ..      ...  ...    ...    ...      ...         ...    ...    ...
# 879       1    1      0      1  83.1583       False      1  False
# 882       3    1      0      0  10.5167       False      0   True
# 885       3    1      0      5  29.1250       False      0  False
# 887       1    1      0      0  30.0000       False      1   True
# 888       3    1      1      2  23.4500       False      0  False
#
# [503 rows x 8 columns]

# %%
df
# Out:
#      survived  pclass  sex  sibsp  parch     fare  adult_male  alive  alone
# 0           0       3    0      1      0   7.2500        True      0  False
# 1           1       1    1      1      0  71.2833       False      1  False
# 2           1       3    1      0      0   7.9250       False      1   True
# 3           1       1    1      1      0  53.1000       False      1  False
# 4           0       3    0      0      0   8.0500        True      0   True
# ..        ...     ...  ...    ...    ...      ...         ...    ...    ...
# 879         1       1    1      0      1  83.1583       False      1  False
# 882         0       3    1      0      0  10.5167       False      0   True
# 885         0       3    1      0      5  29.1250       False      0  False
# 887         1       1    1      0      0  30.0000       False      1   True
# 888         0       3    1      1      2  23.4500       False      0  False
#
# [503 rows x 9 columns]

# %%
y=df.survived

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 879    1
# 882    0
# 885    0
# 887    1
# 888    0
# Name: survived, Length: 503, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn import tree

# %%
classifier = tree.DecisionTreeClassifier(max_depth=1)

# %%
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(classifier,filled=True)
# Out:
# [Text(418.5, 407.70000000000005, 'X[6] <= 0.5\ngini = 0.499\nsamples = 402\nvalue = [210, 192]'),
#  Text(209.25, 135.89999999999998, 'gini = 0.0\nsamples = 210\nvalue = [210, 0]'),
#  Text(627.75, 135.89999999999998, 'gini = 0.0\nsamples = 192\nvalue = [0, 192]')]
